# %% [markdown]
# <a href="https://colab.research.google.com/github/nithinrk11/FlowCast/blob/main/video_detection_stl_webapp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -q -O - ipv4.icanhazip.com
# !git clone https://github.com/nithinrk11/FlowCast.git
# %cd FlowCast
# Install necessary packages
# !pip install streamlit -q
# Out:
# 35.197.65.236
# Cloning into 'FlowCast'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 74 (delta 33), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (74/74), 2.77 MiB | 11.43 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# /content/FlowCast
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 58.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.7 MB/s eta 0:00:00

# %%
# !streamlit run app3.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.197.65.236:8501
#
# npx: installed 22 in 3.315s
# your url is: https://funny-towns-train.loca.lt
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting ultralytics
#   Downloading ultralytics-8.0.225-py3-none-any.whl (660 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.1/660.1 kB 6.7 MB/s eta 0:00:00
# Collecting supervision==0.2.0
#   Downloading supervision-0.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, supervision, ultralytics
# Successfully installed supervision-0.2.0 thop-0.1.1.post2209072238 ultralytics-8.0.225
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-ylh_9tlb
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-ylh_9tlb
#   Resolved https://github.com/facebookresearch/detectron2.git to commit a0e22dbfa791e6235e4f196d5ce25e754d02be31
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.14.1)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.0 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.4 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-23.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.0.225)
# Requirement already satisfied: supervision==0.2.0 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-negurh8o
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-negurh8o
#   Resolved https://github.com/facebookresearch/detectron2.git to commit a0e22dbfa791e6235e4f196d5ce25e754d02be31
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.14.1)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Collecting black (from detectron2==0.6)
#   Using cached black-23.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Using cached portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Using cached pathspec-0.11.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6118754 sha256=b03ff5b2d2deecfbf82119acef74a3883f719b172aa46719923f02e1e025ac0d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m48ysxpz/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=c163e906c761c92cfdf94dbd6e72d8a3294b84100d603bf4439c4f7781b8cc36
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=4f8bbc36f5d7b91e6f282db3ebce14171a125fe609471053660b95f9aea5b465
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.11.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.2 portalocker-2.8.2 yacs-0.1.8
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [14:04:55] WARNING: /workspace/src/common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   warnings.warn(smsg, UserWarning)
# 2023-12-08 14:04:55.922817: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-08 14:04:55.922876: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-08 14:04:55.922926: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6118769 sha256=ba0c935f887aaadaca781ae1de942e9f6495351ee8641efc586dc627866030cb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r8t26lu1/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=284281af8b8efeb01884344bc580f908935e1a0f4158c7e9eca5d66b4063269c
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=fc7abad33aef4851c2819ecd1e76fc4a12ff2914207c7612abf92b99df093a01
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.11.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.2 portalocker-2.8.2 yacs-0.1.8
# [14:05:36] WARNING: /workspace/src/common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.0.225)
# Requirement already satisfied: supervision==0.2.0 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-hlxp7pjq
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-hlxp7pjq
#   Resolved https://github.com/facebookresearch/detectron2.git to commit a0e22dbfa791e6235e4f196d5ce25e754d02be31
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.14.1)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (0.11.2)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 100MB/s]
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.0.225)
# Requirement already satisfied: supervision==0.2.0 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.0) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.0) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# ...
# Speed: 3.8ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 42 persons, 2 backpacks, 4 handbags, 1 frisbee, 1 tennis racket, 16.0ms
# Speed: 3.4ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 3 backpacks, 5 handbags, 1 frisbee, 1 tennis racket, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 2 backpacks, 5 handbags, 1 frisbee, 1 tennis racket, 15.7ms
# Speed: 3.4ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 2 backpacks, 6 handbags, 1 frisbee, 1 tennis racket, 16.0ms
# Speed: 3.4ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 3 backpacks, 2 umbrellas, 6 handbags, 1 snowboard, 1 skateboard, 1 tennis racket, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 3 backpacks, 1 umbrella, 6 handbags, 1 tennis racket, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 1 backpack, 2 umbrellas, 6 handbags, 1 snowboard, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 2 backpacks, 1 umbrella, 6 handbags, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 2 backpacks, 1 umbrella, 7 handbags, 1 snowboard, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 3 backpacks, 1 umbrella, 6 handbags, 1 snowboard, 1 skateboard, 15.8ms
# Speed: 3.3ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 42 persons, 2 backpacks, 1 umbrella, 7 handbags, 1 snowboard, 1 tennis racket, 15.8ms
# Speed: 3.2ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 5 backpacks, 1 umbrella, 3 handbags, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 43 persons, 4 backpacks, 4 handbags, 1 snowboard, 15.4ms
# Speed: 3.2ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 4 backpacks, 3 handbags, 1 snowboard, 15.4ms
# Speed: 3.1ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 43 persons, 7 backpacks, 4 handbags, 1 snowboard, 15.7ms
# Speed: 3.2ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 4 backpacks, 4 handbags, 1 snowboard, 1 skateboard, 16.2ms
# Speed: 3.2ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 41 persons, 1 dog, 4 backpacks, 3 handbags, 2 snowboards, 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 41 persons, 4 backpacks, 3 handbags, 3 snowboards, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 3 backpacks, 4 handbags, 4 snowboards, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 41 persons, 4 backpacks, 5 handbags, 1 snowboard, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 41 persons, 5 backpacks, 4 handbags, 1 snowboard, 15.8ms
# Speed: 3.6ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 4 backpacks, 3 handbags, 2 snowboards, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 4 backpacks, 3 handbags, 1 snowboard, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 35 persons, 3 backpacks, 3 handbags, 1 snowboard, 1 tennis racket, 15.8ms
# Speed: 3.2ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 34 persons, 3 backpacks, 3 handbags, 1 snowboard, 1 tennis racket, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 33 persons, 3 backpacks, 3 handbags, 2 snowboards, 1 tennis racket, 15.8ms
# Speed: 3.2ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 35 persons, 4 backpacks, 4 handbags, 1 snowboard, 1 skateboard, 1 tennis racket, 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 34 persons, 3 backpacks, 4 handbags, 1 skis, 1 snowboard, 1 tennis racket, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 34 persons, 2 backpacks, 4 handbags, 1 snowboard, 1 tennis racket, 15.7ms
# Speed: 3.2ms preprocess, 15.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 35 persons, 2 backpacks, 5 handbags, 1 suitcase, 1 skis, 1 snowboard, 1 tennis racket, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 35 persons, 2 backpacks, 3 handbags, 1 snowboard, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 4 backpacks, 4 handbags, 1 skis, 2 snowboards, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 34 persons, 4 backpacks, 5 handbags, 1 skis, 2 snowboards, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 3 backpacks, 5 handbags, 1 snowboard, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 3 backpacks, 3 handbags, 2 snowboards, 1 skateboard, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 2 backpacks, 3 handbags, 1 snowboard, 16.5ms
# Speed: 3.2ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 3 backpacks, 3 handbags, 1 skis, 15.4ms
# Speed: 3.4ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 backpack, 3 handbags, 1 suitcase, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 1 cat, 1 backpack, 1 handbag, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 1 cat, 1 backpack, 1 handbag, 1 snowboard, 15.4ms
# Speed: 3.5ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 1 cat, 2 handbags, 1 snowboard, 1 skateboard, 15.7ms
# Speed: 3.6ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 1 dog, 2 backpacks, 2 handbags, 1 skateboard, 16.3ms
# Speed: 3.2ms preprocess, 16.3ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 1 dog, 3 backpacks, 2 handbags, 1 snowboard, 1 skateboard, 15.9ms
# Speed: 3.1ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 3 backpacks, 2 handbags, 1 snowboard, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 4 backpacks, 1 handbag, 2 skateboards, 15.6ms
# Speed: 3.3ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 3 backpacks, 1 handbag, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 41 persons, 5 backpacks, 2 handbags, 2 snowboards, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 6 backpacks, 3 handbags, 1 snowboard, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 5 backpacks, 2 handbags, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 3 backpacks, 2 handbags, 15.3ms
# Speed: 3.1ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 3 backpacks, 2 handbags, 15.2ms
# Speed: 3.2ms preprocess, 15.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 6 backpacks, 2 handbags, 1 snowboard, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 6 backpacks, 2 handbags, 1 snowboard, 16.1ms
# Speed: 3.4ms preprocess, 16.1ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 5 backpacks, 3 handbags, 16.1ms
# Speed: 3.3ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 6 backpacks, 2 handbags, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 6 backpacks, 2 handbags, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 1 dog, 6 backpacks, 2 handbags, 15.4ms
# Speed: 3.2ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 6 backpacks, 3 handbags, 1 snowboard, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 7 backpacks, 3 handbags, 2 snowboards, 16.2ms
# Speed: 3.2ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 6 backpacks, 3 handbags, 1 snowboard, 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 6 backpacks, 3 handbags, 2 snowboards, 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 6 backpacks, 3 handbags, 15.4ms
# Speed: 3.1ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 5 backpacks, 2 handbags, 1 skateboard, 15.8ms
# Speed: 3.3ms preprocess, 15.8ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 6 backpacks, 2 handbags, 1 skis, 16.1ms
# Speed: 3.3ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 4 backpacks, 2 handbags, 16.1ms
# Speed: 3.2ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 4 backpacks, 1 handbag, 16.2ms
# Speed: 3.1ms preprocess, 16.2ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 4 backpacks, 2 handbags, 15.7ms
# Speed: 3.4ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 39 persons, 5 backpacks, 2 handbags, 15.8ms
# Speed: 4.2ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 6 backpacks, 1 handbag, 1 frisbee, 16.1ms
# Speed: 3.9ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 5 backpacks, 1 handbag, 1 frisbee, 1 skateboard, 16.0ms
# Speed: 3.5ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 3 backpacks, 1 handbag, 1 frisbee, 1 skis, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 5 backpacks, 2 handbags, 19.3ms
# Speed: 3.2ms preprocess, 19.3ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 7 backpacks, 2 handbags, 1 frisbee, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 6 backpacks, 2 handbags, 1 frisbee, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 34 persons, 1 dog, 5 backpacks, 3 handbags, 16.0ms
# Speed: 3.8ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 6 backpacks, 2 handbags, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 6 backpacks, 4 handbags, 1 snowboard, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 2 dogs, 7 backpacks, 3 handbags, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 7 backpacks, 3 handbags, 1 frisbee, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 8 backpacks, 3 handbags, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 7 backpacks, 3 handbags, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 1 dog, 6 backpacks, 2 handbags, 15.9ms
# Speed: 3.1ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 6 backpacks, 2 handbags, 1 snowboard, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 40 persons, 1 dog, 6 backpacks, 2 handbags, 1 frisbee, 16.0ms
# Speed: 3.6ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 38 persons, 1 dog, 4 backpacks, 2 handbags, 1 skis, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 4 backpacks, 2 handbags, 1 suitcase, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 5 backpacks, 2 handbags, 1 skis, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 37 persons, 4 backpacks, 3 handbags, 2 skiss, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 36 persons, 6 backpacks, 4 handbags, 1 skateboard, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 1280)
# Total Number of Persons Detected(detection sum count from all frames): 13768
# 2023-12-08 14:27:19.985 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 534, in _run_script
#     exec(code, module.__dict__)
#   File "/content/FlowCast/app3.py", line 208, in <module>
#     main()
#   File "/content/FlowCast/app3.py", line 142, in main
#     print("Max Persons Detected in a Frame:", max_persons)
# UnboundLocalError: local variable 'max_persons' referenced before assignment

# %%
import streamlit as st
import subprocess

# Install required packages using subprocess
subprocess.run(["pip", "install", "pandas", "ultralytics", "supervision==0.2.0"])
# Install detectron2 from GitHub
subprocess.run(["pip", "install", "git+https://github.com/facebookresearch/detectron2.git"])

import numpy as np
import supervision as sv
import pandas as pd
import datetime
import pytz
from ultralytics import YOLO

# Install required packages using subprocess
subprocess.run(["pip", "install", "pandas", "ultralytics", "supervision==0.2.0"])
# Install detectron2 from GitHub
subprocess.run(["pip", "install", "git+https://github.com/facebookresearch/detectron2.git"])

# Load YOLO model
model = YOLO('yolov8s.pt')

# Initialize variables for video length, start timestamp, and max persons
video_length = 0  # Initialize to 0
max_persons = 0

def main():
    st.title("Crowd Counting App")
    uploaded_file = st.file_uploader("Choose a video file", type=["mp4", "avi"])

    if uploaded_file is not None:
        st.video(uploaded_file)

        # Save the uploaded video file to a local path
        MALL_VIDEO_PATH = "uploaded_video.mp4"
        with open(MALL_VIDEO_PATH, "wb") as f:
            f.write(uploaded_file.read())

        st.text("Video file saved to: {}".format(MALL_VIDEO_PATH))

        # Initiate polygon zone
        polygon = np.array([
            [0, 200],
            [0, 0],
            [1200, 50],
            [1200, 500]
        ])
        video_info = sv.VideoInfo.from_video_path(MALL_VIDEO_PATH)
        zone = sv.PolygonZone(polygon=polygon, frame_resolution_wh=video_info.resolution_wh)

        # Initiate annotators
        box_annotator = sv.BoxAnnotator(thickness=4, text_thickness=4, text_scale=2)
        zone_annotator = sv.PolygonZoneAnnotator(zone=zone, color=sv.Color.white(), thickness=6, text_thickness=6, text_scale=4)

        # Initialize a global list to store information about detected persons
        person_data = []

        # ... (previous code)

        def process_frame(frame: np.ndarray, frame_index: int) -> np.ndarray:
            global max_persons, video_length

            # detect
            results = model(frame, imgsz=1280)[0]
            detections = sv.Detections.from_yolov8(results)
            detections = detections[detections.class_id == 0]  # Assuming class_id 0 corresponds to persons
            zone.trigger(detections=detections)

            # Update max persons count
            frame_person_count = len(detections)
            max_persons = max(max_persons, frame_person_count)

            # Update video length based on frame index
            video_length = frame_index / video_info.fps  # Calculate video length in seconds

            # Append information about detected persons to the list
            for _ in detections:
                label = f"Person {len(person_data) + 1}"
                person_data.append({'Timestamp': frame_index, 'Label': label})

            # annotate
            labels = [f"Person {i + 1}" for i in range(len(detections))]
            annotated_frame = box_annotator.annotate(scene=frame, detections=detections, labels=labels)
            annotated_frame = zone_annotator.annotate(scene=annotated_frame)

            return annotated_frame

        if st.button("Process Video"):
            # Process the entire video and save the result
            result_video_path_colab = "/content/result2.mp4"
            sv.process_video(source_path=MALL_VIDEO_PATH, target_path=result_video_path_colab, callback=process_frame)

            # Display the processed video
            #st.video(result_video_path_colab)

            # Save the uploaded video file to a local path
            #Processed_video = "processed_video.mp4"
            #with open(result_video_path_colab, "wb") as p:
             #    p.write(result_video_path_colab)

            # Print the total number of persons detected, video length, and max persons
            print("Total Number of Persons Detected(detection sum count from all frames):", len(person_data))

            print("Max Persons Detected in a Frame:", max_persons)
            st.write("Max Persons Detected :", max_persons)
            print("Result saved to CSV:", result_csv_path)

            # Get the current timestamp in the local time zone
            local_timezone = pytz.timezone('Asia/Kolkata')  # Adjust the time zone according to your location
            end_timestamp_local = datetime.datetime.now(tz=local_timezone)

            # Format timestamp as "01-01-2023 12:00:00 PM"
            formatted_timestamp = end_timestamp_local.strftime("%m-%d-%Y %I:%M:%S %p")

            # Create a DataFrame with max_persons count and timestamp
            result_df = pd.DataFrame({
                'Timestamp': [formatted_timestamp],
                'Crowd_Count': [max_persons]
            })

            # Save the DataFrame to a CSV file
            result_csv_path = "/content/crowd_count_result.csv"
            result_df.to_csv(result_csv_path, index=False)

if __name__ == '__main__':
    main()

# %%
import streamlit as st
import subprocess
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import supervision as sv
import pandas as pd
import datetime
import pytz
from ultralytics import YOLO

# Install required packages using subprocess
subprocess.run(["pip", "install", "pandas", "ultralytics", "supervision==0.2.0"])
# Install detectron2 from GitHub
subprocess.run(["pip", "install", "git+https://github.com/facebookresearch/detectron2.git"])

# Load the models
dec = pickle.load(open('dec.pkl', 'rb'))
rf = pickle.load(open('rf.pkl', 'rb'))
xg = pickle.load(open('xg.pkl', 'rb'))
best_xgb = pickle.load(open('best_xgb.pkl', 'rb'))
model = pickle.load(open('model.pkl', 'rb'))

# Declare max_persons and result_csv_path as global variables
max_persons = 0
result_csv_path = None

def classify(num, model):
    if num <= 30:
        return "Low Crowd"
    elif 30 < num <= 70:
        return "Moderate Crowd"
    else:
        return "High Crowd"

def classify_range(crowd_counts, model):
    results = [classify(num, model) for num in crowd_counts]
    return results

def main():
    global result_csv_path  # Declare result_csv_path as global

    st.title("Project FlowCast")
    html_temp = """
    <div style="background-color:teal ;padding:10px">
    <h2 style="color:white;text-align:center;">Crowd Classification</h2>
    </div>
    """
    st.markdown(html_temp, unsafe_allow_html=True)
    activities = ['Decision tree', 'Random forest', 'XGBoost', 'Tuned XGBoost', 'DNN']
    option = st.sidebar.selectbox('Which model would you like to use?', activities)
    st.subheader(option)

    # Install required packages using subprocess
    subprocess.run(["pip", "install", "pandas", "ultralytics", "supervision==0.2.0"])
    # Install detectron2 from GitHub
    subprocess.run(["pip", "install", "git+https://github.com/facebookresearch/detectron2.git"])

    # Load YOLO model
    model = YOLO('yolov8s.pt')

    # Initialize variables for video length, start timestamp, and max persons
    video_length = 0  # Initialize to 0

    uploaded_file = st.file_uploader("Choose a video file", type=["mp4", "avi"])

    if uploaded_file is not None:
        st.video(uploaded_file)

        # Save the uploaded video file to a local path
        MALL_VIDEO_PATH = "uploaded_video.mp4"
        with open(MALL_VIDEO_PATH, "wb") as f:
            f.write(uploaded_file.read())

        st.text("Video file saved to: {}".format(MALL_VIDEO_PATH))

        # Initiate polygon zone
        polygon = np.array([
            [0, 200],
            [0, 0],
            [1200, 50],
            [1200, 500]
        ])
        video_info = sv.VideoInfo.from_video_path(MALL_VIDEO_PATH)
        zone = sv.PolygonZone(polygon=polygon, frame_resolution_wh=video_info.resolution_wh)

        # Initiate annotators
        box_annotator = sv.BoxAnnotator(thickness=4, text_thickness=4, text_scale=2)
        zone_annotator = sv.PolygonZoneAnnotator(zone=zone, color=sv.Color.white(), thickness=6, text_thickness=6, text_scale=4)

        # Initialize a global list to store information about detected persons
        person_data = []

        def process_frame(frame: np.ndarray, frame_index: int) -> np.ndarray:
            global max_persons, result_csv_path  # Declare max_persons and result_csv_path as global

            # detect
            results = model(frame, imgsz=1280)[0]
            detections = sv.Detections.from_yolov8(results)
            detections = detections[detections.class_id == 0]  # Assuming class_id 0 corresponds to persons
            zone.trigger(detections=detections)

            # Update max persons count
            frame_person_count = len(detections)
            max_persons = max(max_persons, frame_person_count)

            # Update video length based on frame index
            video_length = frame_index / video_info.fps  # Calculate video length in seconds

            # Append information about detected persons to the list
            for _ in detections:
                label = f"Person {len(person_data) + 1}"
                person_data.append({'Timestamp': frame_index, 'Label': label})

            # annotate
            labels = [f"Person {i + 1}" for i in range(len(detections))]
            annotated_frame = box_annotator.annotate(scene=frame, detections=detections, labels=labels)
            annotated_frame = zone_annotator.annotate(scene=annotated_frame)

            return annotated_frame

            result_csv_path = None

        if st.button("Process Video"):
            # Process the entire video and save the result
            result_video_path_colab = "/content/result2.mp4"
            sv.process_video(source_path=MALL_VIDEO_PATH, target_path=result_video_path_colab, callback=process_frame)

            # Display the processed video
            # st.video(result_video_path_colab)

            # Print the total number of persons detected, video length, and max persons
            print("Total Number of Persons Detected(detection sum count from all frames):", len(person_data))
            print("Max Persons Detected in a Frame:", max_persons)
            st.write("Max Persons Detected :", max_persons)

            # Get the current timestamp in the local time zone
            local_timezone = pytz.timezone('Asia/Kolkata')  # Adjust the time zone according to your location
            end_timestamp_local = datetime.datetime.now(tz=local_timezone)

            # Format timestamp as "01-01-2023 12:00:00 PM"
            formatted_timestamp = end_timestamp_local.strftime("%m-%d-%Y %I:%M:%S %p")

            # Create a DataFrame with max_persons count and timestamp
            result_df = pd.DataFrame({
                'Timestamp': [formatted_timestamp],
                'Crowd_Count': [max_persons]
            })

            # Save the DataFrame to a CSV file
            result_csv_path = "/content/crowd_count_result.csv"
            result_df.to_csv(result_csv_path, index=False)

    # Assuming the column containing crowd counts is named 'Crowd_Count'
    if result_csv_path is not None:
        data = pd.read_csv(result_csv_path)

        if 'Crowd_Count' in data.columns and 'Timestamp' in data.columns:
            data['Timestamp'] = pd.to_datetime(data['Timestamp'])

            # Resample the data for daily, weekly, and monthly averages
            daily_avg = data.resample('D', on='Timestamp').mean()
            weekly_avg = data.resample('W-Mon', on='Timestamp').mean()
            monthly_avg = data.resample('M', on='Timestamp').mean()

            crowd_counts = data['Crowd_Count'].tolist()
            timestamps = data['Timestamp']

            results = classify_range(crowd_counts, dec) if option == 'Decision tree' else \
                classify_range(crowd_counts, rf) if option == 'Random forest' else \
                classify_range(crowd_counts, xg) if option == 'XGBoost' else \
                classify_range(crowd_counts, best_xgb) if option == 'Tuned XGBoost' else \
                classify_range(crowd_counts, model)

            overall_avg = np.mean(crowd_counts)

            fig, ax = plt.subplots(figsize=(10, 6))
            sns.lineplot(x=timestamps, y=crowd_counts, hue=results, palette="viridis", ax=ax, label='Crowd Count')
            sns.lineplot(x=daily_avg.index, y=daily_avg['Crowd_Count'], color='blue', label='Daily Avg', ax=ax)
            sns.lineplot(x=weekly_avg.index, y=weekly_avg['Crowd_Count'], color='green', label='Weekly Avg', ax=ax)
            sns.lineplot(x=monthly_avg.index, y=monthly_avg['Crowd_Count'], color='orange', label='Monthly Avg', ax=ax)
            plt.axhline(overall_avg, color='red', linestyle='--', label='Overall Avg')
            plt.title('Time vs Crowd Count with Average Estimation')
            plt.xlabel('Timestamp')
            plt.ylabel('Crowd Count')
            plt.legend()
            st.pyplot(fig)

            results_df = pd.DataFrame({'Timestamp': timestamps, 'Crowd_Count': crowd_counts, 'Classification': results})
            st.write(results_df)
        else:
            st.error("Please make sure your CSV file has columns named 'Timestamp' and 'Crowd_Count.'")

if __name__ == '__main__':
    main()

# %%
import streamlit as st
import subprocess
# Install required packages using subprocess
subprocess.run(["pip", "install", "pandas", "ultralytics", "supervision==0.2.0"])
# Install detectron2 from GitHub
subprocess.run(["pip", "install", "git+https://github.com/facebookresearch/detectron2.git"])
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import supervision as sv
import pandas as pd
import datetime
import pytz
from ultralytics import YOLO



# Load the models
dec = pickle.load(open('dec.pkl', 'rb'))
rf = pickle.load(open('rf.pkl', 'rb'))
xg = pickle.load(open('xg.pkl', 'rb'))
best_xgb = pickle.load(open('best_xgb.pkl', 'rb'))
model = pickle.load(open('model.pkl', 'rb'))

# Declare max_persons and result_csv_path as global variables
max_persons = 0
result_csv_path = None

def classify(num, model):
    if num <= 30:
        return "Low Crowd"
    elif 30 < num <= 70:
        return "Moderate Crowd"
    else:
        return "High Crowd"

def classify_range(crowd_counts, model):
    results = [classify(num, model) for num in crowd_counts]
    return results

def main():
    global result_csv_path  # Declare result_csv_path as global

    st.title("Project FlowCast")
    html_temp = """
    <div style="background-color:teal ;padding:10px">
    <h2 style="color:white;text-align:center;">Crowd Classification</h2>
    </div>
    """
    st.markdown(html_temp, unsafe_allow_html=True)
    activities = ['Decision tree', 'Random forest', 'XGBoost', 'Tuned XGBoost', 'DNN']
    option = st.sidebar.selectbox('Which model would you like to use?', activities)
    st.subheader(option)

    # Install required packages using subprocess
    subprocess.run(["pip", "install", "pandas", "ultralytics", "supervision==0.2.0"])
    # Install detectron2 from GitHub
    subprocess.run(["pip", "install", "git+https://github.com/facebookresearch/detectron2.git"])

    # Load YOLO model
    model = YOLO('yolov8s.pt')

    # Initialize variables for video length, start timestamp, and max persons
    video_length = 0  # Initialize to 0

    uploaded_file = st.file_uploader("Choose a video file", type=["mp4", "avi"])

    if uploaded_file is not None:
        st.video(uploaded_file)

        # Save the uploaded video file to a local path
        MALL_VIDEO_PATH = "uploaded_video.mp4"
        with open(MALL_VIDEO_PATH, "wb") as f:
            f.write(uploaded_file.read())

        st.text("Video file saved to: {}".format(MALL_VIDEO_PATH))

        # Initiate polygon zone
        polygon = np.array([
            [0, 200],
            [0, 0],
            [1200, 50],
            [1200, 500]
        ])
        video_info = sv.VideoInfo.from_video_path(MALL_VIDEO_PATH)
        zone = sv.PolygonZone(polygon=polygon, frame_resolution_wh=video_info.resolution_wh)

        # Initiate annotators
        box_annotator = sv.BoxAnnotator(thickness=4, text_thickness=4, text_scale=2)
        zone_annotator = sv.PolygonZoneAnnotator(zone=zone, color=sv.Color.white(), thickness=6, text_thickness=6, text_scale=4)

        # Initialize a global list to store information about detected persons
        person_data = []

        def process_frame(frame: np.ndarray, frame_index: int) -> np.ndarray:
            global max_persons, result_csv_path  # Declare max_persons and result_csv_path as global

            # detect
            results = model(frame, imgsz=1280)[0]
            detections = sv.Detections.from_yolov8(results)
            detections = detections[detections.class_id == 0]  # Assuming class_id 0 corresponds to persons
            zone.trigger(detections=detections)

            # Update max persons count
            frame_person_count = len(detections)
            max_persons = max(max_persons, frame_person_count)

            # Update video length based on frame index
            video_length = frame_index / video_info.fps  # Calculate video length in seconds

            # Append information about detected persons to the list
            for _ in detections:
                label = f"Person {len(person_data) + 1}"
                person_data.append({'Timestamp': frame_index, 'Label': label})

            # annotate
            labels = [f"Person {i + 1}" for i in range(len(detections))]
            annotated_frame = box_annotator.annotate(scene=frame, detections=detections, labels=labels)
            annotated_frame = zone_annotator.annotate(scene=annotated_frame)

            return annotated_frame

            result_csv_path = None

        if st.button("Process Video"):
            # Process the entire video and save the result
            result_video_path_colab = "/content/result2.mp4"
            sv.process_video(source_path=MALL_VIDEO_PATH, target_path=result_video_path_colab, callback=process_frame)

            # Display the processed video
            # st.video(result_video_path_colab)

            # Print the total number of persons detected, video length, and max persons
            print("Total Number of Persons Detected(detection sum count from all frames):", len(person_data))
            print("Max Persons Detected in a Frame:", max_persons)
            st.write("Max Persons Detected :", max_persons)

            # Get the current timestamp in the local time zone
            local_timezone = pytz.timezone('Asia/Kolkata')  # Adjust the time zone according to your location
            end_timestamp_local = datetime.datetime.now(tz=local_timezone)

            # Format timestamp as "01-01-2023 12:00:00 PM"
            formatted_timestamp = end_timestamp_local.strftime("%m-%d-%Y %I:%M:%S %p")

            # Create a DataFrame with max_persons count and timestamp
            result_df = pd.DataFrame({
                'Timestamp': [formatted_timestamp],
                'Crowd_Count': [max_persons]
            })

            # Save the DataFrame to a CSV file
            result_csv_path = "/content/crowd_count_result.csv"
            result_df.to_csv(result_csv_path, index=False)

    # Assuming the column containing crowd counts is named 'Crowd_Count'
    if result_csv_path is not None:
        data = pd.read_csv(result_csv_path)

        if 'Crowd_Count' in data.columns and 'Timestamp' in data.columns:
            data['Timestamp'] = pd.to_datetime(data['Timestamp'])

            # Resample the data for daily, weekly, and monthly averages
            daily_avg = data.resample('D', on='Timestamp').mean()
            weekly_avg = data.resample('W-Mon', on='Timestamp').mean()
            monthly_avg = data.resample('M', on='Timestamp').mean()

            crowd_counts = data['Crowd_Count'].tolist()
            timestamps = data['Timestamp']

            results = classify_range(crowd_counts, dec) if option == 'Decision tree' else \
                classify_range(crowd_counts, rf) if option == 'Random forest' else \
                classify_range(crowd_counts, xg) if option == 'XGBoost' else \
                classify_range(crowd_counts, best_xgb) if option == 'Tuned XGBoost' else \
                classify_range(crowd_counts, model)

            overall_avg = np.mean(crowd_counts)

            fig, ax = plt.subplots(figsize=(10, 6))
            sns.lineplot(x=timestamps, y=crowd_counts, hue=results, palette="viridis", ax=ax, label='Crowd Count')
            sns.lineplot(x=daily_avg.index, y=daily_avg['Crowd_Count'], color='blue', label='Daily Avg', ax=ax)
            sns.lineplot(x=weekly_avg.index, y=weekly_avg['Crowd_Count'], color='green', label='Weekly Avg', ax=ax)
            sns.lineplot(x=monthly_avg.index, y=monthly_avg['Crowd_Count'], color='orange', label='Monthly Avg', ax=ax)
            plt.axhline(overall_avg, color='red', linestyle='--', label='Overall Avg')
            plt.title('Time vs Crowd Count with Average Estimation')
            plt.xlabel('Timestamp')
            plt.ylabel('Crowd Count')
            plt.legend()
            st.pyplot(fig)


            results_df = pd.DataFrame({'Timestamp': timestamps, 'Crowd_Count': crowd_counts, 'Classification': results})
            st.write(results_df)

        else:
            st.error("Please make sure your CSV file has columns named 'Timestamp' and 'Crowd_Count.'")

if __name__ == '__main__':
    main()
